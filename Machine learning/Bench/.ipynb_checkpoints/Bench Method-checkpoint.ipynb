# %%
# Analyse :

# IMPORTS :

import os
import pandas as pd
from pandas import *
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import *
from tensorflow.python.keras import optimizers as opt
import matplotlib.pyplot as plt
# %matplotlib inline

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def Analyse_One(y_actual,y_pred,index,name,n_analyse):
    
    curr_analyse = pd.DataFrame()
    curr_analyse['Date'] = index
    curr_analyse.set_index(['Date'],inplace=True)
    
    curr_analyse['Y'] = y_actual
    curr_analyse['P'] = y_pred
    
    # RMSE :
    rmse = ((y_pred - y_actual) ** 2).mean() ** .5
    
    # MAE :
    mae = np.mean(abs(y_actual-y_pred))
    
    # MAPE :
    mape =  mean_absolute_percentage_error(y_actual, y_pred)
    
    curr_analyse['RMSE'] = rmse
    curr_analyse['MAE'] = mae
    curr_analyse['MAPE'] = mape
    
    
    # Export / Save :
    
    outdir = r"C:\Users\bapti\Documents\Equancy\Machine learning\Bench\1"
    outdir = outdir[:-1]
    outdir = outdir + name
    
    outname = name + "_" + str(n_analyse) + ".csv"

    
    if not os.path.exists(outdir):
        os.mkdir(outdir)

    fullname = os.path.join(outdir, outname)    

    curr_analyse.to_csv(fullname)
    
    
def Compile (index,name,n_it):
    
    
    
    
    adress = r"C:\Users\bapti\Documents\Equancy\Machine learning\Bench\1"
    adress = adress[:-1]
    adress = adress + name
    
    
    
    outname_perso = name + "_0.csv"
  
    
    if not os.path.exists(adress):
        os.mkdir(adress)

    full_dir_0 = os.path.join(adress, outname_perso)
    
    
    comp_analyse = pd.read_csv(full_dir_0)
    
    
    
    for i in range(1,n_it):
    
        
    
        outname_perso = name +"_" + str(i) + ".csv"
        
        full_dir = os.path.join(adress, outname_perso)
        
        curr_data = pd.read_csv(full_dir)
        
        curr_sum = pd.DataFrame()
        
        
        
        list_modif_str = ['Y','P',"RMSE","MAE","MAPE"]
        
        for text in list_modif_str:
            ty1 = text + "1"
            ty2 = text + "2"
            
            curr_sum[ty1] = comp_analyse[text]
            curr_sum[ty2] = curr_data[text]
            comp_analyse[text] = curr_sum[[ty1, ty2]].mean(axis=1)
            
            
     # Export / Save :
    
    
    
    
    outname = name + "_final.csv"

    
    if not os.path.exists(adress):
        os.mkdir(adress)

    fullname = os.path.join(adress, outname)    

    comp_analyse.to_csv(fullname)
    
    
    
    
def affichage(name):
    
    adress = r"C:\Users\bapti\Documents\Equancy\Machine learning\Bench\1"
    adress = adress[:-1]
    adress = adress + name
    
    outname_perso = name + "_final.csv"
    
    full_dir = os.path.join(adress, outname_perso)
        
    curr_data = pd.read_csv(full_dir)
    
    title = 'EDF Prediction _ ' + name
    
    
    plt.figure(figsize=(10,6))
    
    
    plt.plot(curr_data['Y'], color='blue', label='Actual')
    plt.plot(curr_data['P'] , color='red', label='Predicted')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Global_active_power')
    plt.legend()
    
    text_fig = 'rmse = ' + str(curr_data['RMSE'][0]) + "\n"
    text_fig += 'mae = ' + str(curr_data['MAE'][0]) + "\n"
    text_fig += 'mape = ' + str(curr_data['MAPE'][0]) + "\n"
    text_fig += 'epochs = 2'
    
    plt.figtext(0.5, -0.2, text_fig, ha="center", fontsize=18, bbox={"facecolor":"cyan", "alpha":0.5, "pad":5})
    
    
    name_doc = name + ".pdf"
    
    full_save = os.path.join(adress, name_doc)
    
    plt.savefig(full_save, bbox_inches = "tight")  
    
    plt.show()
    
    
    
def Test_method(df, test_size,pred,n_it,name):
    
    index = df.index[-test_size:]
    
    for i in range(n_it):
        y_actual,y_pred = pred(df, test_size)
        Analyse_One(y_actual,y_pred,index,name,i)
    
    
    Compile (index,name,n_it)
    affichage(name)

# %%
# Data :

df = pd.read_csv('Days.csv')
df["Date"] = pd.to_datetime(df['timestamp'])
df.set_index(['Date'],inplace=True)

df = pd.DataFrame(df, columns=['Y'])

# %%
# GRU :

def GRU_model (df, test_size):
    
    # Prepare Data :
    
    index = df.index[-test_size:]

    shifted_df = df.shift()

    concat_df = [df,shifted_df]

    data = pd.concat(concat_df,axis = 1)
    data.fillna(0, inplace = True)



    data = np.array(data)

    train, test = data[0:-test_size], data[-test_size:]
    
    
    

    scaler = MinMaxScaler()
    train_scaled = scaler.fit_transform(train)
    test_scaled = scaler.transform(test)

    

    # train data 
    y_train = train_scaled[:,-1] 
    X_train = train_scaled[:,0:-1] 
    X_train = X_train.reshape(len(X_train),1,1)
    # données de test 
    y_test = test_scaled[:,-1] 
    X_test = test_scaled[:,0:-1]
    
    
    
    
    # Model :

    model = Sequential()
    model.add(GRU(75, input_shape=(1,1)))
    model.add(Dense(2))  
    opt = keras.optimizers.Adam(learning_rate=0.01) #learning_rate=0.001
    model.compile(loss='mean_squared_error', optimizer= opt, metrics = ['accuracy'])
    model.fit(X_train, y_train, epochs=2, batch_size=20, shuffle=False)
    
    
    
    X_test = X_test.reshape(X_test.size,1,1)
    
    
    y_pred = model.predict(X_test)
    
    
    predictions_trad = scaler.inverse_transform(y_pred)

    predictions_col = []

    for i in predictions_trad :
        predictions_col.append(i[0])

    
    dic = {'Y': predictions_col}

    y_pred = pd.DataFrame(data = dic)

    y_pred['Date'] = index

    y_pred.set_index(['Date'],inplace=True)
    
    
    
    
    
    
    return df['Y'][-test_size:].values,y_pred.values

# %%
# LSTM_Keras :

# IMPORTS :

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout


def LSTM_Keras_model (df, test_size):
    
    df_arg = df
    
    train_size = df.size - test_size
    
    # Data Normalization :
    scaler = MinMaxScaler(feature_range = (0, 1))

    df = scaler.fit_transform(df)
    
    features_set = []
    labels = []

    # On fait des groupes de 60
    # (l'article disait que por prévoir les stocks d'Apple c'est ce qu'il avait de meilleur avec ses test)
    for i in range(0, test_size):
        features_set.append(df[train_size+i-60:train_size+i, 0])
        labels.append(df[train_size+i, 0])

    features_set, labels = np.array(features_set), np.array(labels)

    # On formate les données pour le LSTM :
    features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))
    
    
    # Création - LSTM :

    # Classe du modèle :
    model = Sequential()

    # Layer 1 - LSTM 50 units:
    model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))

    # Dropout :
    # On oublie constamment une partie pour éviter le surentraînement
    model.add(Dropout(0.2))

    # On ajoute de la même manière 3 autre couche :
    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(units=50, return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(units=50))
    model.add(Dropout(0.2))

    # On veut une sortie on mets donc une couche dense avec 1 neurone en sortie
    model.add(Dense(units = 1))
    
    # Compilation du LSTM :

    # On utilise l'optimiseur adam
    # Erreur quadratique moyenne comme fonction d'ajustement

    model.compile(optimizer = 'adam', loss = 'mean_squared_error')

    # Entraînement du modèle :

    model.fit(features_set, labels, epochs = 2, batch_size = 32)
    
    
    
    # Préparation des données de test :

    
    test_inputs = df_arg['Y'][-test_size-60:].values

    test_inputs = test_inputs.reshape(-1,1)
    test_inputs = scaler.transform(test_inputs)

    test_features = []
    for i in range(60, 60+test_size):
        test_features.append(test_inputs[i-60:i, 0])

    # Mise au format 3D :
    test_features = np.array(test_features)
    
    test_features = np.reshape(test_features, (test_features.shape[0], test_features.shape[1], 1))
    
    # Prédiction :

    predictions = model.predict(test_features)
    predictions = scaler.inverse_transform(predictions)
    
    return df_arg['Y'][-test_size:].values,predictions

# %%
# Final Process :

Test_method(df, 90,GRU_model,10,"GRU")
Test_method(df, 90,LSTM_Keras_model,10,"LSTM_Keras_model")
# Out:
# Epoch 1/150
# 51/51 [==============================] - 2s 2ms/step - loss: 0.0388 - accuracy: 9.9404e-04
# Epoch 2/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.0030
# Epoch 3/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.0030
# Epoch 4/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 0.0020
# Epoch 5/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.0020
# Epoch 6/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.0020
# Epoch 7/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.0020
# Epoch 8/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.0020
# Epoch 9/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.0020
# Epoch 10/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.0020
# Epoch 11/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.0020
# Epoch 12/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.0020
# Epoch 13/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.0020
# Epoch 14/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.0020
# Epoch 15/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.0020
# Epoch 16/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.0020
# Epoch 17/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 9.9404e-04
# Epoch 18/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 9.9404e-04
# Epoch 19/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.0020
# Epoch 20/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 9.9404e-04
# Epoch 21/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.0020
# Epoch 22/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 9.9404e-04
# Epoch 23/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.0020
# Epoch 24/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 9.9404e-04
# Epoch 25/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.0020
# Epoch 26/150
# 51/51 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 0.0020
# Epoch 27/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.0020
# Epoch 28/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.0020
# Epoch 29/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.0020
# Epoch 30/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.0020
# Epoch 31/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.0020
# Epoch 32/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.0020
# Epoch 33/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.0020
# Epoch 34/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.0020
# Epoch 35/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.0020
# Epoch 36/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.0020
# Epoch 37/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.0020
# Epoch 38/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.0020
# Epoch 39/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 40/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 41/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 42/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 43/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 44/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 45/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0020
# Epoch 46/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 47/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0020
# Epoch 48/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0000e+00
# Epoch 49/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 50/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 51/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0030
# Epoch 52/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 53/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 54/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 55/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 56/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 57/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 58/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 59/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 60/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 61/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 62/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 63/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 64/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 65/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 66/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 67/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 68/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 69/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 70/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 71/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 72/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 73/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 74/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 75/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 76/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 77/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 78/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 79/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 80/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 81/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 82/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 83/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 84/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 85/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 86/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 87/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 88/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 89/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 90/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 91/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 92/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 93/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 94/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 95/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 96/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 97/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 98/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 99/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 100/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 101/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 102/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 103/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 104/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 105/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 106/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 107/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 108/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 109/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 110/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 111/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 112/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 113/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 114/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 115/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 116/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 117/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 118/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 119/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 120/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 121/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 122/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 123/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 124/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 125/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 126/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 127/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 128/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 129/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 130/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 131/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 132/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 133/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 134/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 135/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 136/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 137/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 138/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 139/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 140/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 141/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 142/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 143/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 144/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 145/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 146/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 147/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 148/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 149/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 150/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 1/150
# 51/51 [==============================] - 2s 2ms/step - loss: 0.0372 - accuracy: 0.0020
# Epoch 2/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 9.9404e-04
# Epoch 3/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.0020
# Epoch 4/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 0.0020
# Epoch 5/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.0020
# Epoch 6/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.0020
# Epoch 7/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.0020
# Epoch 8/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.0020
# Epoch 9/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.0020
# Epoch 10/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.0020
# Epoch 11/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.0020
# Epoch 12/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 9.9404e-04
# Epoch 13/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 9.9404e-04
# Epoch 14/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.0020
# Epoch 15/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 9.9404e-04
# Epoch 16/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.0020
# Epoch 17/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 9.9404e-04
# Epoch 18/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.0020
# Epoch 19/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 9.9404e-04
# Epoch 20/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 9.9404e-04
# Epoch 21/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 9.9404e-04
# Epoch 22/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 9.9404e-04
# Epoch 23/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 9.9404e-04
# Epoch 24/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 9.9404e-04
# Epoch 25/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 9.9404e-04
# Epoch 26/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 9.9404e-04
# Epoch 27/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 9.9404e-04
# Epoch 28/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 9.9404e-04
# Epoch 29/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 9.9404e-04
# Epoch 30/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 9.9404e-04
# Epoch 31/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 9.9404e-04
# Epoch 32/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 9.9404e-04
# Epoch 33/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 9.9404e-04
# Epoch 34/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 9.9404e-04
# Epoch 35/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 9.9404e-04
# Epoch 36/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 9.9404e-04
# Epoch 37/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 9.9404e-04
# Epoch 38/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 9.9404e-04
# Epoch 39/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 9.9404e-04
# Epoch 40/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 9.9404e-04
# Epoch 41/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 9.9404e-04
# Epoch 42/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 9.9404e-04
# Epoch 43/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 9.9404e-04
# Epoch 44/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 45/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 46/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 47/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 48/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 49/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 9.9404e-04
# Epoch 50/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 51/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 52/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 53/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 54/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 55/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 56/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 57/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 58/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0000e+00
# Epoch 59/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 60/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 61/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 62/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 63/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 64/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 65/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 66/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 67/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 68/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 69/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 70/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 71/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 72/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 73/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 74/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 75/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 76/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 77/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 78/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 79/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 80/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 81/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 82/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 83/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 84/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 85/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 86/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 87/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 88/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 89/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 90/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 91/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 92/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 93/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 94/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 95/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 96/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 97/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 98/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 99/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 100/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 101/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 102/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 103/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 104/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 105/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 106/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 107/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 108/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 109/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 110/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 111/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 112/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 113/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 114/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 115/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 116/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 117/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 118/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 119/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 120/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 121/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 122/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 123/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 124/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 125/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 126/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 127/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 128/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 129/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 130/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 131/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 132/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 133/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 134/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 135/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 136/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 137/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 138/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 139/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 140/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 141/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 142/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 143/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 144/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 145/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 146/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 147/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 148/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 149/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 150/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 1/150
# 51/51 [==============================] - 2s 2ms/step - loss: 0.0409 - accuracy: 9.9404e-04
# Epoch 2/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.0020
# Epoch 3/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.0020
# Epoch 4/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.0020
# Epoch 5/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.0020
# Epoch 6/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 9.9404e-04
# Epoch 7/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 9.9404e-04
# Epoch 8/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 9.9404e-04
# Epoch 9/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 9.9404e-04
# Epoch 10/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 9.9404e-04
# Epoch 11/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 9.9404e-04
# Epoch 12/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 9.9404e-04
# Epoch 13/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 9.9404e-04
# Epoch 14/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 9.9404e-04
# Epoch 15/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 9.9404e-04
# Epoch 16/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 9.9404e-04
# Epoch 17/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 9.9404e-04
# Epoch 18/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 9.9404e-04
# Epoch 19/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 9.9404e-04
# Epoch 20/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 9.9404e-04
# Epoch 21/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 9.9404e-04
# Epoch 22/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 9.9404e-04
# Epoch 23/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 9.9404e-04
# Epoch 24/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 9.9404e-04
# Epoch 25/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 9.9404e-04
# Epoch 26/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.0020
# Epoch 27/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.0020
# Epoch 28/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.0020
# Epoch 29/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.0020
# Epoch 30/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.0020
# Epoch 31/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.0020
# Epoch 32/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.0020
# Epoch 33/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.0020
# Epoch 34/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.0020
# Epoch 35/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.0020
# Epoch 36/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.0020
# Epoch 37/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.0020
# Epoch 38/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.0020
# Epoch 39/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 40/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 41/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 42/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.0020
# Epoch 43/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0020
# Epoch 44/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0020
# Epoch 45/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0020
# Epoch 46/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0020
# Epoch 47/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.0020
# Epoch 48/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 49/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 50/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 51/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 52/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 53/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 54/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 55/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 56/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 57/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 58/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 59/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 60/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 61/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.0020
# Epoch 62/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 9.9404e-04
# Epoch 63/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 64/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 65/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 66/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 67/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 68/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 69/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 70/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 71/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 72/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 73/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 74/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 75/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 76/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 77/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 78/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 79/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 9.9404e-04
# Epoch 80/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 81/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 82/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.0020
# Epoch 83/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 84/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 85/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 86/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 87/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 88/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 89/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 90/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 91/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 92/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 93/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 94/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 95/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 96/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 97/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 98/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 99/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 100/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 101/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 102/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 103/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 104/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 105/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 106/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 107/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 108/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 109/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 110/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 111/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 112/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 113/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 114/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 9.9404e-04
# Epoch 115/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 116/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 117/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 118/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 119/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 120/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 121/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 122/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 123/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0020
# Epoch 124/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.0030
# Epoch 125/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 126/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 127/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 128/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 129/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 130/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 131/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 132/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 133/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 134/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 135/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 136/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 137/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 138/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 139/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 140/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 141/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 9.9404e-04
# Epoch 142/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 143/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 144/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 145/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 146/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 147/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 148/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 149/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0030
# Epoch 150/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.0020
# Epoch 1/150
# 51/51 [==============================] - 2s 2ms/step - loss: 0.0405 - accuracy: 9.9404e-04
# Epoch 2/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.0020
# Epoch 3/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 0.0030
# Epoch 4/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 9.9404e-04
# Epoch 5/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 9.9404e-04
# Epoch 6/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 9.9404e-04
# Epoch 7/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 9.9404e-04
# Epoch 8/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 9.9404e-04
# Epoch 9/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.0020
# Epoch 10/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.0020
# Epoch 11/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 0.0020
# Epoch 12/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.0020
# Epoch 13/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.0020
# Epoch 14/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.0020
# Epoch 15/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.0020
# Epoch 16/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.0020
# Epoch 17/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 9.9404e-04
# Epoch 18/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 9.9404e-04
# Epoch 19/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 9.9404e-04
# Epoch 20/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0169 - accuracy: 9.9404e-04
# Epoch 21/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 9.9404e-04
# Epoch 22/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 9.9404e-04
# Epoch 23/150
# 51/51 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 9.9404e-04
# Epoch 24/150
# ...
# Epoch 107/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0122
# Epoch 108/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0130
# Epoch 109/150
# 3/3 [==============================] - 0s 82ms/step - loss: 0.0120
# Epoch 110/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0122
# Epoch 111/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0130
# Epoch 112/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0134
# Epoch 113/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0115
# Epoch 114/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0128
# Epoch 115/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0122
# Epoch 116/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0118
# Epoch 117/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0139
# Epoch 118/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0133
# Epoch 119/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0138
# Epoch 120/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0123
# Epoch 121/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0112
# Epoch 122/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0119
# Epoch 123/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0130
# Epoch 124/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0120
# Epoch 125/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0141
# Epoch 126/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0134
# Epoch 127/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0130
# Epoch 128/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0127
# Epoch 129/150
# 3/3 [==============================] - 0s 83ms/step - loss: 0.0128
# Epoch 130/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0130
# Epoch 131/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0121
# Epoch 132/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0134
# Epoch 133/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0115
# Epoch 134/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0137
# Epoch 135/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0126
# Epoch 136/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0141
# Epoch 137/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0130
# Epoch 138/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0130
# Epoch 139/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0124
# Epoch 140/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0106
# Epoch 141/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0121
# Epoch 142/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0125
# Epoch 143/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0129
# Epoch 144/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0131
# Epoch 145/150
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0117
# Epoch 146/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0127
# Epoch 147/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0127
# Epoch 148/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0132
# Epoch 149/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0143
# Epoch 150/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0126
# C:\Users\bapti\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# Epoch 1/150
# 3/3 [==============================] - 6s 86ms/step - loss: 0.1657
# Epoch 2/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0531
# Epoch 3/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0400
# Epoch 4/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0187
# Epoch 5/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0252
# Epoch 6/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0250
# Epoch 7/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0159
# Epoch 8/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0178
# Epoch 9/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0179
# Epoch 10/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0143
# Epoch 11/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0144
# Epoch 12/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0165
# Epoch 13/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0129
# Epoch 14/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0127
# Epoch 15/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0158
# Epoch 16/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0137
# Epoch 17/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0146
# Epoch 18/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0146
# Epoch 19/150
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0141
# Epoch 20/150
# 3/3 [==============================] - 0s 96ms/step - loss: 0.0143
# Epoch 21/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0139
# Epoch 22/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0125
# Epoch 23/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0125
# Epoch 24/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0139
# Epoch 25/150
# 3/3 [==============================] - 0s 93ms/step - loss: 0.0142
# Epoch 26/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0140
# Epoch 27/150
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0140
# Epoch 28/150
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0124
# Epoch 29/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0115
# Epoch 30/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0136
# Epoch 31/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0127
# Epoch 32/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0134
# Epoch 33/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0128
# Epoch 34/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0137
# Epoch 35/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0136
# Epoch 36/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0130
# Epoch 37/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0126
# Epoch 38/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0137
# Epoch 39/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0129
# Epoch 40/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0141
# Epoch 41/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0121
# Epoch 42/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0120
# Epoch 43/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0141
# Epoch 44/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0122
# Epoch 45/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0111
# Epoch 46/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0145
# Epoch 47/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0138
# Epoch 48/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0132
# Epoch 49/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0133
# Epoch 50/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0146
# Epoch 51/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0131
# Epoch 52/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0144
# Epoch 53/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0127
# Epoch 54/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0136
# Epoch 55/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0138
# Epoch 56/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0134
# Epoch 57/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0132
# Epoch 58/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0138
# Epoch 59/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0116
# Epoch 60/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0142
# Epoch 61/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0133
# Epoch 62/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0136
# Epoch 63/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0129
# Epoch 64/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0127
# Epoch 65/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0139
# Epoch 66/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0126
# Epoch 67/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0126
# Epoch 68/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0140
# Epoch 69/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0135
# Epoch 70/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0125
# Epoch 71/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0120
# Epoch 72/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0130
# Epoch 73/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0135
# Epoch 74/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0117
# Epoch 75/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0133
# Epoch 76/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0132
# Epoch 77/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0131
# Epoch 78/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0155
# Epoch 79/150
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0132
# Epoch 80/150
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0136
# Epoch 81/150
# 3/3 [==============================] - 0s 99ms/step - loss: 0.0134
# Epoch 82/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0137
# Epoch 83/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0125
# Epoch 84/150
# 3/3 [==============================] - 0s 94ms/step - loss: 0.0125
# Epoch 85/150
# 3/3 [==============================] - 0s 95ms/step - loss: 0.0117
# Epoch 86/150
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0143
# Epoch 87/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0137
# Epoch 88/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0110
# Epoch 89/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0144
# Epoch 90/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0132
# Epoch 91/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0118
# Epoch 92/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0120
# Epoch 93/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0145
# Epoch 94/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0134
# Epoch 95/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0138
# Epoch 96/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0130
# Epoch 97/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0147
# Epoch 98/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0130
# Epoch 99/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0148
# Epoch 100/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0138
# Epoch 101/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0119
# Epoch 102/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0132
# Epoch 103/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0123
# Epoch 104/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0141
# Epoch 105/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0137
# Epoch 106/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0134
# Epoch 107/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0126
# Epoch 108/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0118
# Epoch 109/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0132
# Epoch 110/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0129
# Epoch 111/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0146
# Epoch 112/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0129
# Epoch 113/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0120
# Epoch 114/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0131
# Epoch 115/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0102
# Epoch 116/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0109
# Epoch 117/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0140
# Epoch 118/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0131
# Epoch 119/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0135
# Epoch 120/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0140
# Epoch 121/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0136
# Epoch 122/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0121
# Epoch 123/150
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0131
# Epoch 124/150
# 3/3 [==============================] - 0s 91ms/step - loss: 0.0127
# Epoch 125/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0121
# Epoch 126/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0134
# Epoch 127/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0148
# Epoch 128/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0122
# Epoch 129/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0131
# Epoch 130/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0126
# Epoch 131/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0142
# Epoch 132/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0135
# Epoch 133/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0127
# Epoch 134/150
# 3/3 [==============================] - 0s 88ms/step - loss: 0.0129
# Epoch 135/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0133
# Epoch 136/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0130
# Epoch 137/150
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0126
# Epoch 138/150
# 3/3 [==============================] - 0s 102ms/step - loss: 0.0133
# Epoch 139/150
# 3/3 [==============================] - 0s 100ms/step - loss: 0.0127
# Epoch 140/150
# 3/3 [==============================] - 0s 97ms/step - loss: 0.0132
# Epoch 141/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0130
# Epoch 142/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0125
# Epoch 143/150
# 3/3 [==============================] - 0s 98ms/step - loss: 0.0128
# Epoch 144/150
# 3/3 [==============================] - 0s 92ms/step - loss: 0.0123
# Epoch 145/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0120
# Epoch 146/150
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0132
# Epoch 147/150
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0141
# Epoch 148/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0133
# Epoch 149/150
# 3/3 [==============================] - 0s 90ms/step - loss: 0.0115
# Epoch 150/150
# 3/3 [==============================] - 0s 87ms/step - loss: 0.0133
# C:\Users\bapti\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
