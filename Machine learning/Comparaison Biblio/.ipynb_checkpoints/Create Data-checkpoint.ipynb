# %%
# Imports :

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Database :

data = pd.read_csv('DATABASE.txt', sep=";", header=None, na_values=['?'])
data
# Out:
# C:\Users\bapti\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2,3,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                   0         1                    2                      3  \
# 0              Date      Time  Global_active_power  Global_reactive_power
# 1        16/12/2006  17:24:00                4.216                  0.418
# 2        16/12/2006  17:25:00                5.360                  0.436
# 3        16/12/2006  17:26:00                5.374                  0.498
# 4        16/12/2006  17:27:00                5.388                  0.502
# ...             ...       ...                  ...                    ...
# 2075255  26/11/2010  20:58:00                0.946                    0.0
# 2075256  26/11/2010  20:59:00                0.944                    0.0
# ...

# %%
# On sélectionne 3 ans 2007 à 2009

data = data.rename(columns=data.iloc[0]).drop(data.index[0])

data["Time_index2"] = data["Date"] + " " + data["Time"]

data["timestamp"] = pd.to_datetime(data['Time_index2'], format='%d/%m/%Y %H:%M:%S')
data.set_index(['timestamp'],inplace=True)



data["Global_active_power"] = data["Global_active_power"].astype(float)

data.head()

df = pd.DataFrame(data, columns=['Global_active_power'])

df = df.rename(columns={'Global_active_power': 'Y'})

mask = (df.index > '2007-1-1') & (df.index <= '2009-12-31')

data = df.loc[mask]

# On retire les valeurs manquantes
data.dropna(inplace = True)

data
# Out:
# <ipython-input-3-b87e7451d3e0>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace = True)
#                          Y
# timestamp
# 2007-01-01 00:01:00  2.552
# 2007-01-01 00:02:00  2.550
# 2007-01-01 00:03:00  2.550
# 2007-01-01 00:04:00  2.554
# 2007-01-01 00:05:00  2.550
# ...                    ...
# 2009-12-30 23:56:00  0.420
# 2009-12-30 23:57:00  0.410
# 2009-12-30 23:58:00  0.350
# 2009-12-30 23:59:00  0.344
# 2009-12-31 00:00:00  0.342
#
# [1568454 rows x 1 columns]

# %%
# Resample :

Mins = data['Y'].resample(rule = 'min').mean()
Hours = data['Y'].resample(rule = 'H').mean()
Days = data['Y'].resample(rule = 'D').mean()
Month = data['Y'].resample(rule = 'M').mean()

Days.to_csv(r'C:\Users\bapti\Documents\Equancy\Machine learning\Comparaison Biblio\Days.csv', index = True)

Days.plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
""""
# SMA DATA : (Simple Mean Average)

# Mins :

data['Mins'] = data['Y'].rolling(window = 60).mean()

# Hours :

data['Hours'] = data['Mins'].rolling(window = 60).mean()

# Days :

data['Days'] = data['Hours'].rolling(window = 24).mean()

data[200:1000].plot()

""""
# Out:
#   File "<ipython-input-5-29c829d9dbef>", line 18
#     """"
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
# EWMA DATA : (Exponentially Weighted Moving Average)
