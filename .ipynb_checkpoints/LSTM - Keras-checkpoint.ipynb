# %%
# IMPORTS :

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# DATABASE :

data = pd.read_csv('DATABASE.txt', sep=";", header=None, na_values=['?'])

data = data[:5000]

data = data.rename(columns=data.iloc[0]).drop(data.index[0])

data["Time_index2"] = data["Date"] + " " + data["Time"]

data["timestamp"] = pd.to_datetime(data['Time_index2'], format='%d/%m/%Y %H:%M:%S')
data.set_index(['timestamp'],inplace=True)

data["Global_active_power"] = data["Global_active_power"].astype(float)

data.head()

df = pd.DataFrame(data, columns=['Global_active_power'])

df = df.rename(columns={'Global_active_power': 'Y'})

data = df

df = df[:1261]

df.head()
# Out:
# C:\Users\bapti\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2,3,4,5,6,7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                          Y
# timestamp
# 2006-12-16 17:24:00  4.216
# 2006-12-16 17:25:00  5.360
# 2006-12-16 17:26:00  5.374
# 2006-12-16 17:27:00  5.388
# 2006-12-16 17:28:00  3.666

# %%
# Data Normalization :

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

df = scaler.fit_transform(df)
df
# Out:
# array([[0.53466667],
#        [0.6872    ],
#        [0.68906667],
#        ...,
#        [0.2552    ],
#        [0.25546667],
#        [0.25493333]])

# %%
features_set = []
labels = []

# On fait des groupes de 60
# (l'article disait que por prévoir les stocks d'Apple c'est ce qu'il avait de meilleur avec ses test)
for i in range(60, 1260):
    features_set.append(df[i-60:i, 0])
    labels.append(df[i, 0])

features_set, labels = np.array(features_set), np.array(labels)

# On formate les données pour le LSTM :
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))

# %%
# Le LSTM :

# IMPORTS :

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
# Création :

# Classe du modèle :
model = Sequential()

# Layer 1 - LSTM 50 units:
model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))

# Dropout :
# On oublie constamment une partie pour éviter le surentraînement
model.add(Dropout(0.2))

# On ajoute de la même manière 3 autre couche :
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

# On veut une sortie on mets donc une couche dense avec 1 neurone en sortie
model.add(Dense(units = 1))

# %%
# Compilation du LSTM :

# On utilise l'optimiseur adam
# Erreur quadratique moyenne comme fonction d'ajustement

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Entraînement du modèle :

model.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 10s 76ms/step - loss: 0.0252
# Epoch 2/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0180
# Epoch 3/100
# 38/38 [==============================] - 3s 76ms/step - loss: 0.0182
# Epoch 4/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0169
# Epoch 5/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0163
# Epoch 6/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0163
# Epoch 7/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0154
# Epoch 8/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0151
# Epoch 9/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0150
# Epoch 10/100
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0157
# Epoch 11/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0147
# Epoch 12/100
# 38/38 [==============================] - 3s 79ms/step - loss: 0.0140
# Epoch 13/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0149
# Epoch 14/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0142
# Epoch 15/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0145
# Epoch 16/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0145
# Epoch 17/100
# 38/38 [==============================] - 3s 76ms/step - loss: 0.0141
# Epoch 18/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0137
# Epoch 19/100
# 38/38 [==============================] - 3s 77ms/step - loss: 0.0140
# Epoch 20/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0144
# Epoch 21/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0138
# Epoch 22/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0139
# Epoch 23/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0138
# Epoch 24/100
# 38/38 [==============================] - 3s 78ms/step - loss: 0.0134
# Epoch 25/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0138
# Epoch 26/100
# 38/38 [==============================] - 3s 82ms/step - loss: 0.0137
# Epoch 27/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0135
# Epoch 28/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0139
# Epoch 29/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0137
# Epoch 30/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0136
# Epoch 31/100
# 38/38 [==============================] - 3s 81ms/step - loss: 0.0137
# Epoch 32/100
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0133
# Epoch 33/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0135
# Epoch 34/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0137
# Epoch 35/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0137
# Epoch 36/100
# 38/38 [==============================] - 3s 83ms/step - loss: 0.0134
# Epoch 37/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0138
# Epoch 38/100
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0134
# Epoch 39/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0135
# Epoch 40/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.0139
# Epoch 41/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0135
# Epoch 42/100
# 38/38 [==============================] - 4s 92ms/step - loss: 0.0131
# Epoch 43/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0135
# Epoch 44/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0136
# Epoch 45/100
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0131
# Epoch 46/100
# 38/38 [==============================] - 4s 101ms/step - loss: 0.0132
# Epoch 47/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0133
# Epoch 48/100
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0130
# Epoch 49/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0130
# Epoch 50/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0134
# Epoch 51/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0131
# Epoch 52/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0131
# Epoch 53/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0131
# Epoch 54/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0129
# Epoch 55/100
# 38/38 [==============================] - 3s 84ms/step - loss: 0.0128
# Epoch 56/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0134
# Epoch 57/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0129
# Epoch 58/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0131
# Epoch 59/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0128
# Epoch 60/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0133
# Epoch 61/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0130
# Epoch 62/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0131
# Epoch 63/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0131
# Epoch 64/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0129
# Epoch 65/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0130
# Epoch 66/100
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0131
# Epoch 67/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0130
# Epoch 68/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0127
# Epoch 69/100
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0128
# Epoch 70/100
# 38/38 [==============================] - 3s 85ms/step - loss: 0.0128
# Epoch 71/100
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0129
# Epoch 72/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0127
# Epoch 73/100
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0128
# Epoch 74/100
# 38/38 [==============================] - 3s 86ms/step - loss: 0.0125
# Epoch 75/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0128
# Epoch 76/100
# 38/38 [==============================] - 4s 97ms/step - loss: 0.0128
# Epoch 77/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0125
# Epoch 78/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0126
# Epoch 79/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0127
# Epoch 80/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0127
# Epoch 81/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0127
# Epoch 82/100
# 38/38 [==============================] - 4s 95ms/step - loss: 0.0125
# Epoch 83/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0124
# Epoch 84/100
# 38/38 [==============================] - 3s 87ms/step - loss: 0.0123
# Epoch 85/100
# 38/38 [==============================] - 3s 92ms/step - loss: 0.0126
# Epoch 86/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0124
# Epoch 87/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0121
# Epoch 88/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0125: 0s - lo
# Epoch 89/100
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0121
# Epoch 90/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0121
# Epoch 91/100
# 38/38 [==============================] - 4s 100ms/step - loss: 0.0120
# Epoch 92/100
# 38/38 [==============================] - 4s 94ms/step - loss: 0.0120
# Epoch 93/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0124
# Epoch 94/100
# 38/38 [==============================] - 4s 96ms/step - loss: 0.0123
# Epoch 95/100
# 38/38 [==============================] - 4s 98ms/step - loss: 0.0120
# Epoch 96/100
# 38/38 [==============================] - 4s 93ms/step - loss: 0.0122
# Epoch 97/100
# 38/38 [==============================] - 3s 89ms/step - loss: 0.0122
# Epoch 98/100
# 38/38 [==============================] - 3s 91ms/step - loss: 0.0120
# Epoch 99/100
# 38/38 [==============================] - 3s 90ms/step - loss: 0.0121
# Epoch 100/100
# 38/38 [==============================] - 3s 88ms/step - loss: 0.0118

# %%
# Préparation des données de test :

test_inputs = data['Y'][1261 - 60:].values

test_inputs = test_inputs.reshape(-1,1)
test_inputs = scaler.transform(test_inputs)

test_features = []
for i in range(60, 80):
    test_features.append(test_inputs[i-60:i, 0])

# Mise au format 3D :
test_features = np.array(test_features)
test_features = np.reshape(test_features, (test_features.shape[0], test_features.shape[1], 1))

test_features
# Out:
# C:\Users\bapti\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([[[0.1656    ],
#         [0.1648    ],
#         [0.16533333],
#         ...,
#         [0.2552    ],
#         [0.25546667],
#         [0.25493333]],
#
#        [[0.1648    ],
#         [0.16533333],
#         [0.16533333],
#         ...,
#         [0.25546667],
#         [0.25493333],
#         [0.25333333]],
#
#        [[0.16533333],
#         [0.16533333],
#         [0.16453333],
#         ...,
#         [0.25493333],
#         [0.25333333],
#         [0.25733333]],
#
#        ...,
#
#        [[0.21573333],
#         [0.2152    ],
#         [0.21386667],
#         ...,
#         [0.25493333],
#         [0.25386667],
#         [0.25386667]],
#
#        [[0.2152    ],
#         [0.21386667],
#         [0.21386667],
#         ...,
#         [0.25386667],
#         [0.25386667],
#         [0.25386667]],
#
#        [[0.21386667],
#         [0.21386667],
#         [0.21333333],
#         ...,
#         [0.25386667],
#         [0.25386667],
#         [0.2536    ]]])

# %%
# Prédiction :

predictions = model.predict(test_features)
predictions = scaler.inverse_transform(predictions)

# %%
# Affichage :

plt.figure(figsize=(10,6))
plt.plot(data['Y'][1261:1281].values, color='blue', label='Actual')
plt.plot(predictions , color='red', label='Predicted')
plt.title('EDF Prediction')
plt.xlabel('Date')
plt.ylabel('Global_active_power')
plt.legend()
plt.show()
